# %%
import pandas as pd
import requests

# %%
response=requests.get(url that shows json file)

# %%
response.json()['results']

# %%
pd.DataFrame(response.json()['results'].head(2)

# %%
pd.DataFrame(response.json()['results'].head(2)[['id','title','overview']]

# %%
df.head()

# %%
df=pd.DataFrame()

# %%
for i in range(1,429):
    response=requests.get(url that shows json file)
    temp_df=pd.DataFrame(response.json()['results'].head(2)[['id','title','overview']]
    df=df.append(temp_df,ignore_index=True)

# %%
# convert innto csv
df.to_csv('movies')
